# %% [markdown]
# Поиск инсайтов в данных продуктовых магазинов компании. В файле содержится информация о покупках людей.
# Необходимо выяснить, какие пары товаров пользователи чаще всего покупают вместе. По сути, необходимо найти паттерны покупок, что позволит оптимизировать размещение продуктов в магазине для удобства пользователей и увеличения выручки.
# _________
# **Описание данных:**
#  id – означает покупку (в одну покупку входят все товары, купленные пользователем во время 1 похода в магазин)
#  Товар – наименование товара
#  Количество – число единиц купленного товара

# %%
import pandas as pd
from tqdm.auto import tqdm
import scipy.special

# %%
data = pd.read_csv('https://stepik.org/media/attachments/lesson/409319/test1_completed.csv')
data.head(5)
# Out:
#       id            Товар  Количество
# 0  17119            Лимон         1.1
# 1  17119  Лимон оранжевый         0.7
# 2  17119        Лук-порей        10.0
# 3  17119     Лук репчатый         2.5
# 4  17119    Малина свежая         1.0

# %%
# Число уникальных товаров:
data['Товар'].nunique()
# Out:
# 199

# %%
# Список всех товаров:
products = list(data['Товар'].unique())
products
# Out:
# ['Лимон',
#  'Лимон оранжевый',
#  'Лук-порей',
#  'Лук репчатый',
#  'Малина свежая',
#  'Морковь немытая',
#  'Черешня сушеная',
#  'Изюм Султана',
#  'Капуста цветная',
#  'Бразильский орех',
#  'Дыня Гуляби',
#  'Шпинат мини',
#  'Изюм Голд',
#  'Огурцы Луховицкие',
#  'Чеснок весовой',
#  'Огурцы Белоруссия',
#  'Черешня отборная',
#  'Абрикосы молдавские',
#  'Кукуруза мини',
#  'Грибы лисички',
#  'Слива Президент',
#  'Апельсины столовые',
#  'Кукуруза свежая',
#  'Салат Руккола',
#  'Гранат',
#  'Подпись открытки',
#  'Лук зеленый',
#  'Цукаты (брусочки)',
#  'Кокос питьевой',
#  'Петрушка',
#  'Помидоры Парадайз',
#  'Ягоды Годжи',
#  'Укроп',
#  'Черника свежая',
#  'Персики',
#  'Арбуз',
#  'Салат Айсберг',
#  'Галангал корень',
#  'Петрушка Кудрявая',
#  'Яблоки Гала',
#  'Курага коричневая',
#  'Горох стручковый',
#  'Персики узбекские',
#  'Персик сушеный',
#  'Груша Форел',
#  'Яблоки Айдаред',
#  'Яблоки Симиренко',
#  'Кабачки',
#  'Кинза',
#  'Морковь мытая',
#  'Капуста Кольраби',
#  'Груша Аббат',
#  'Шпинат',
#  'Вишня садовая',
#  'Сахар-песок, 5кг',
#  'Сельдерей корень',
#  'Груша Пакхам',
#  'Чеснок молодой',
#  'Мандарины',
#  'Мангостин свежий',
#  'Груша садовая',
#  'Помидоры черри',
#  'Бананы мини',
#  'Баклажаны грунтовые',
#  'Салат Романо',
#  'Яблоки Мутсу',
#  'Компотная смесь',
#  'Курага темно-оранжевая',
#  'Дыня цукаты',
#  'Миндаль жареный',
#  'Урюк сушеный',
#  'Лайм',
#  'Пекан очищенный',
#  'Салат Фриллис',
#  'Бананы',
#  'Салат Корн',
#  'Инжир сушеный',
#  'Инжир свежий',
#  'Груша вяленая',
#  'Салат Радичио',
#  'Кумкват сушеный',
#  'Персики армянские',
#  'Щавель',
#  'Огурцы длинноплодные',
#  'Малина садовая',
#  'Букет "Фаворит"',
#  'Семена льна',
#  'Базилик красный',
#  'Тыква',
#  'Сельдерей лист',
#  'Персики азербайджанские',
#  'Вишня вяленая',
#  'Миндаль сырой',
#  'Кабачки желтые',
#  'Яблоки Голден',
#  'Базилик зеленый',
#  'Фундук жареный',
#  'Кизил свежий',
#  'Боярышник сушеный',
#  'Огурцы Миринда',
#  'Букет "Брокколи"',
#  'Помидоры дагестанские',
#  'Салат Китайский',
#  'Груша Конференц',
#  'Огурцы Кураж',
#  'Фасоль стручковая',
#  'Цуккини',
#  'Мята',
#  'Кунжут белый',
#  'Слива красная',
#  'Букет "Кассиопея"',
#  'Салат Фризе',
#  'Барбарис сушеный',
#  'Шалфей',
#  'Манго зеленое',
#  'Открытка Love',
#  'Яблоки Джонаголд',
#  'Лук-шалот',
#  'Огурцы бакинские',
#  'Помело сушеное',
#  'Ананасовые кольца',
#  'Рамбутан',
#  'Кешью сырой',
#  'Яблоки Чемпион',
#  'Редис',
#  'Тамарилло',
#  'Капуста Савойская',
#  'Свекла',
#  'Грибы вешенки',
#  'Абрикос вяленый',
#  'Рычал-Су, 1л',
#  'Букет "Закат"',
#  'Дыня Колхозница',
#  'Тыква миндальная',
#  'Яблоки сушеные',
#  'Капуста белокочанная',
#  'Финики королевские',
#  'Банановые чипсы',
#  'Кокосовая стружка',
#  'Грибы шампиньоны',
#  'Фенхель свежий',
#  'Салат микс',
#  'Папайя сушеная',
#  'Манго цукаты',
#  'Папайя',
#  'Манго желтое',
#  'Нектарины',
#  'Ананас Gold',
#  'Картофель черри',
#  'Авокадо ХАСС',
#  'Цыпленок-корнишон замороженный',
#  'Арбуз овальный',
#  'Пастернак корень',
#  'Баклажаны белые',
#  'Букет "Оазис"',
#  'Брусника свежая',
#  'Кешью жареный',
#  'Букет "Колорит"',
#  'Курага',
#  'Миндальные лепестки',
#  'Лонган',
#  'Розмарин',
#  'Грибы Еринги',
#  'Слива азербайджанская',
#  'Имбирь корень',
#  'Тимьян (чабрец)',
#  'Крыжовник свежий',
#  'Кролик фермерский',
#  'Шиповник',
#  'Грейпфрут красный',
#  'Изюм Малаяр',
#  'Букет "Оранж"',
#  'Салат Московский',
#  'Алыча вяленая',
#  'Кунжут черный',
#  'Облепиха',
#  'Пленка пищевая',
#  'Клубника сушеная',
#  'Лук-резанец (шнитт-лук)',
#  'Цукаты (шайбы)',
#  'Киви',
#  'Тархун (эстрагон)',
#  'Яблоки сезонные',
#  'Ежевика свежая',
#  'Цукаты (лепестки)',
#  'Семена Чиа',
#  'Салат Латук',
#  'Маракуйя',
#  'Мак пищевой',
#  'Кумкват свежий',
#  'Дыня "Косичка"',
#  'Физалис',
#  'Яблоки Фуджи',
#  'Фундук сырой',
#  'Помело',
#  'Капуста краснокочанная',
#  'Лемонграсс',
#  'Авокадо стандарт',
#  'Малина сушеная']

# %%
# Составим список всех возможных пар товаров:
pairs = []
for i in range(len(products)):
    for j in range(i+1, len(products)):
        pairs.append([products[i],products[j]])
pairs
# Out:
# [['Лимон', 'Лимон оранжевый'],
#  ['Лимон', 'Лук-порей'],
#  ['Лимон', 'Лук репчатый'],
#  ['Лимон', 'Малина свежая'],
#  ['Лимон', 'Морковь немытая'],
#  ['Лимон', 'Черешня сушеная'],
#  ['Лимон', 'Изюм Султана'],
#  ['Лимон', 'Капуста цветная'],
#  ['Лимон', 'Бразильский орех'],
#  ['Лимон', 'Дыня Гуляби'],
#  ['Лимон', 'Шпинат мини'],
#  ['Лимон', 'Изюм Голд'],
#  ['Лимон', 'Огурцы Луховицкие'],
#  ['Лимон', 'Чеснок весовой'],
#  ['Лимон', 'Огурцы Белоруссия'],
#  ['Лимон', 'Черешня отборная'],
#  ['Лимон', 'Абрикосы молдавские'],
#  ['Лимон', 'Кукуруза мини'],
#  ['Лимон', 'Грибы лисички'],
#  ['Лимон', 'Слива Президент'],
#  ['Лимон', 'Апельсины столовые'],
#  ['Лимон', 'Кукуруза свежая'],
#  ['Лимон', 'Салат Руккола'],
#  ['Лимон', 'Гранат'],
#  ['Лимон', 'Подпись открытки'],
#  ['Лимон', 'Лук зеленый'],
#  ['Лимон', 'Цукаты (брусочки)'],
#  ['Лимон', 'Кокос питьевой'],
#  ['Лимон', 'Петрушка'],
#  ['Лимон', 'Помидоры Парадайз'],
#  ['Лимон', 'Ягоды Годжи'],
#  ['Лимон', 'Укроп'],
#  ['Лимон', 'Черника свежая'],
#  ['Лимон', 'Персики'],
#  ['Лимон', 'Арбуз'],
#  ['Лимон', 'Салат Айсберг'],
#  ['Лимон', 'Галангал корень'],
#  ['Лимон', 'Петрушка Кудрявая'],
#  ['Лимон', 'Яблоки Гала'],
#  ['Лимон', 'Курага коричневая'],
#  ['Лимон', 'Горох стручковый'],
#  ['Лимон', 'Персики узбекские'],
#  ['Лимон', 'Персик сушеный'],
#  ['Лимон', 'Груша Форел'],
#  ['Лимон', 'Яблоки Айдаред'],
#  ['Лимон', 'Яблоки Симиренко'],
#  ['Лимон', 'Кабачки'],
#  ['Лимон', 'Кинза'],
#  ['Лимон', 'Морковь мытая'],
#  ['Лимон', 'Капуста Кольраби'],
#  ['Лимон', 'Груша Аббат'],
#  ['Лимон', 'Шпинат'],
#  ['Лимон', 'Вишня садовая'],
#  ['Лимон', 'Сахар-песок, 5кг'],
#  ['Лимон', 'Сельдерей корень'],
#  ['Лимон', 'Груша Пакхам'],
#  ['Лимон', 'Чеснок молодой'],
#  ['Лимон', 'Мандарины'],
#  ['Лимон', 'Мангостин свежий'],
#  ['Лимон', 'Груша садовая'],
#  ['Лимон', 'Помидоры черри'],
#  ['Лимон', 'Бананы мини'],
#  ['Лимон', 'Баклажаны грунтовые'],
#  ['Лимон', 'Салат Романо'],
#  ['Лимон', 'Яблоки Мутсу'],
#  ['Лимон', 'Компотная смесь'],
#  ['Лимон', 'Курага темно-оранжевая'],
#  ['Лимон', 'Дыня цукаты'],
#  ['Лимон', 'Миндаль жареный'],
#  ['Лимон', 'Урюк сушеный'],
#  ['Лимон', 'Лайм'],
#  ['Лимон', 'Пекан очищенный'],
#  ['Лимон', 'Салат Фриллис'],
#  ['Лимон', 'Бананы'],
#  ['Лимон', 'Салат Корн'],
#  ['Лимон', 'Инжир сушеный'],
#  ['Лимон', 'Инжир свежий'],
#  ['Лимон', 'Груша вяленая'],
#  ['Лимон', 'Салат Радичио'],
#  ['Лимон', 'Кумкват сушеный'],
#  ['Лимон', 'Персики армянские'],
#  ['Лимон', 'Щавель'],
#  ['Лимон', 'Огурцы длинноплодные'],
#  ['Лимон', 'Малина садовая'],
#  ['Лимон', 'Букет "Фаворит"'],
#  ['Лимон', 'Семена льна'],
#  ['Лимон', 'Базилик красный'],
#  ['Лимон', 'Тыква'],
#  ['Лимон', 'Сельдерей лист'],
#  ['Лимон', 'Персики азербайджанские'],
#  ['Лимон', 'Вишня вяленая'],
#  ['Лимон', 'Миндаль сырой'],
#  ['Лимон', 'Кабачки желтые'],
#  ['Лимон', 'Яблоки Голден'],
#  ['Лимон', 'Базилик зеленый'],
#  ['Лимон', 'Фундук жареный'],
#  ['Лимон', 'Кизил свежий'],
#  ['Лимон', 'Боярышник сушеный'],
#  ['Лимон', 'Огурцы Миринда'],
#  ['Лимон', 'Букет "Брокколи"'],
#  ['Лимон', 'Помидоры дагестанские'],
#  ['Лимон', 'Салат Китайский'],
#  ['Лимон', 'Груша Конференц'],
#  ['Лимон', 'Огурцы Кураж'],
#  ['Лимон', 'Фасоль стручковая'],
#  ['Лимон', 'Цуккини'],
#  ['Лимон', 'Мята'],
#  ['Лимон', 'Кунжут белый'],
#  ['Лимон', 'Слива красная'],
#  ['Лимон', 'Букет "Кассиопея"'],
#  ['Лимон', 'Салат Фризе'],
#  ['Лимон', 'Барбарис сушеный'],
#  ['Лимон', 'Шалфей'],
#  ['Лимон', 'Манго зеленое'],
#  ['Лимон', 'Открытка Love'],
#  ['Лимон', 'Яблоки Джонаголд'],
#  ['Лимон', 'Лук-шалот'],
#  ['Лимон', 'Огурцы бакинские'],
#  ['Лимон', 'Помело сушеное'],
#  ['Лимон', 'Ананасовые кольца'],
#  ['Лимон', 'Рамбутан'],
#  ['Лимон', 'Кешью сырой'],
#  ['Лимон', 'Яблоки Чемпион'],
#  ['Лимон', 'Редис'],
#  ['Лимон', 'Тамарилло'],
#  ['Лимон', 'Капуста Савойская'],
#  ['Лимон', 'Свекла'],
#  ['Лимон', 'Грибы вешенки'],
#  ['Лимон', 'Абрикос вяленый'],
#  ['Лимон', 'Рычал-Су, 1л'],
#  ['Лимон', 'Букет "Закат"'],
#  ['Лимон', 'Дыня Колхозница'],
#  ['Лимон', 'Тыква миндальная'],
#  ['Лимон', 'Яблоки сушеные'],
#  ['Лимон', 'Капуста белокочанная'],
#  ['Лимон', 'Финики королевские'],
#  ['Лимон', 'Банановые чипсы'],
#  ['Лимон', 'Кокосовая стружка'],
#  ['Лимон', 'Грибы шампиньоны'],
#  ['Лимон', 'Фенхель свежий'],
#  ['Лимон', 'Салат микс'],
#  ['Лимон', 'Папайя сушеная'],
#  ['Лимон', 'Манго цукаты'],
#  ['Лимон', 'Папайя'],
#  ['Лимон', 'Манго желтое'],
#  ['Лимон', 'Нектарины'],
#  ['Лимон', 'Ананас Gold'],
#  ['Лимон', 'Картофель черри'],
#  ['Лимон', 'Авокадо ХАСС'],
#  ['Лимон', 'Цыпленок-корнишон замороженный'],
#  ['Лимон', 'Арбуз овальный'],
#  ['Лимон', 'Пастернак корень'],
#  ['Лимон', 'Баклажаны белые'],
#  ['Лимон', 'Букет "Оазис"'],
#  ['Лимон', 'Брусника свежая'],
#  ['Лимон', 'Кешью жареный'],
#  ['Лимон', 'Букет "Колорит"'],
#  ['Лимон', 'Курага'],
#  ['Лимон', 'Миндальные лепестки'],
#  ['Лимон', 'Лонган'],
#  ['Лимон', 'Розмарин'],
#  ['Лимон', 'Грибы Еринги'],
#  ['Лимон', 'Слива азербайджанская'],
#  ['Лимон', 'Имбирь корень'],
#  ['Лимон', 'Тимьян (чабрец)'],
#  ['Лимон', 'Крыжовник свежий'],
#  ['Лимон', 'Кролик фермерский'],
#  ['Лимон', 'Шиповник'],
#  ['Лимон', 'Грейпфрут красный'],
#  ['Лимон', 'Изюм Малаяр'],
#  ['Лимон', 'Букет "Оранж"'],
#  ['Лимон', 'Салат Московский'],
#  ['Лимон', 'Алыча вяленая'],
#  ['Лимон', 'Кунжут черный'],
#  ['Лимон', 'Облепиха'],
#  ['Лимон', 'Пленка пищевая'],
#  ['Лимон', 'Клубника сушеная'],
#  ['Лимон', 'Лук-резанец (шнитт-лук)'],
#  ['Лимон', 'Цукаты (шайбы)'],
#  ['Лимон', 'Киви'],
#  ['Лимон', 'Тархун (эстрагон)'],
#  ['Лимон', 'Яблоки сезонные'],
#  ['Лимон', 'Ежевика свежая'],
#  ['Лимон', 'Цукаты (лепестки)'],
#  ['Лимон', 'Семена Чиа'],
#  ['Лимон', 'Салат Латук'],
#  ['Лимон', 'Маракуйя'],
#  ['Лимон', 'Мак пищевой'],
#  ['Лимон', 'Кумкват свежий'],
#  ['Лимон', 'Дыня "Косичка"'],
#  ['Лимон', 'Физалис'],
#  ['Лимон', 'Яблоки Фуджи'],
#  ['Лимон', 'Фундук сырой'],
#  ['Лимон', 'Помело'],
#  ['Лимон', 'Капуста краснокочанная'],
#  ['Лимон', 'Лемонграсс'],
#  ['Лимон', 'Авокадо стандарт'],
#  ['Лимон', 'Малина сушеная'],
#  ['Лимон оранжевый', 'Лук-порей'],
#  ['Лимон оранжевый', 'Лук репчатый'],
#  ['Лимон оранжевый', 'Малина свежая'],
#  ['Лимон оранжевый', 'Морковь немытая'],
#  ['Лимон оранжевый', 'Черешня сушеная'],
#  ['Лимон оранжевый', 'Изюм Султана'],
#  ['Лимон оранжевый', 'Капуста цветная'],
#  ['Лимон оранжевый', 'Бразильский орех'],
#  ['Лимон оранжевый', 'Дыня Гуляби'],
#  ['Лимон оранжевый', 'Шпинат мини'],
#  ['Лимон оранжевый', 'Изюм Голд'],
#  ['Лимон оранжевый', 'Огурцы Луховицкие'],
#  ['Лимон оранжевый', 'Чеснок весовой'],
#  ['Лимон оранжевый', 'Огурцы Белоруссия'],
#  ['Лимон оранжевый', 'Черешня отборная'],
#  ['Лимон оранжевый', 'Абрикосы молдавские'],
#  ['Лимон оранжевый', 'Кукуруза мини'],
#  ['Лимон оранжевый', 'Грибы лисички'],
#  ['Лимон оранжевый', 'Слива Президент'],
#  ['Лимон оранжевый', 'Апельсины столовые'],
#  ['Лимон оранжевый', 'Кукуруза свежая'],
#  ['Лимон оранжевый', 'Салат Руккола'],
#  ['Лимон оранжевый', 'Гранат'],
#  ['Лимон оранжевый', 'Подпись открытки'],
#  ['Лимон оранжевый', 'Лук зеленый'],
#  ['Лимон оранжевый', 'Цукаты (брусочки)'],
#  ['Лимон оранжевый', 'Кокос питьевой'],
#  ['Лимон оранжевый', 'Петрушка'],
#  ['Лимон оранжевый', 'Помидоры Парадайз'],
#  ['Лимон оранжевый', 'Ягоды Годжи'],
#  ['Лимон оранжевый', 'Укроп'],
#  ['Лимон оранжевый', 'Черника свежая'],
#  ['Лимон оранжевый', 'Персики'],
#  ['Лимон оранжевый', 'Арбуз'],
#  ['Лимон оранжевый', 'Салат Айсберг'],
#  ['Лимон оранжевый', 'Галангал корень'],
#  ['Лимон оранжевый', 'Петрушка Кудрявая'],
#  ['Лимон оранжевый', 'Яблоки Гала'],
#  ['Лимон оранжевый', 'Курага коричневая'],
#  ['Лимон оранжевый', 'Горох стручковый'],
#  ['Лимон оранжевый', 'Персики узбекские'],
#  ['Лимон оранжевый', 'Персик сушеный'],
#  ['Лимон оранжевый', 'Груша Форел'],
#  ['Лимон оранжевый', 'Яблоки Айдаред'],
#  ['Лимон оранжевый', 'Яблоки Симиренко'],
#  ['Лимон оранжевый', 'Кабачки'],
#  ['Лимон оранжевый', 'Кинза'],
#  ['Лимон оранжевый', 'Морковь мытая'],
#  ['Лимон оранжевый', 'Капуста Кольраби'],
#  ['Лимон оранжевый', 'Груша Аббат'],
#  ['Лимон оранжевый', 'Шпинат'],
#  ['Лимон оранжевый', 'Вишня садовая'],
#  ['Лимон оранжевый', 'Сахар-песок, 5кг'],
#  ['Лимон оранжевый', 'Сельдерей корень'],
#  ['Лимон оранжевый', 'Груша Пакхам'],
#  ['Лимон оранжевый', 'Чеснок молодой'],
#  ['Лимон оранжевый', 'Мандарины'],
#  ['Лимон оранжевый', 'Мангостин свежий'],
#  ['Лимон оранжевый', 'Груша садовая'],
#  ['Лимон оранжевый', 'Помидоры черри'],
#  ['Лимон оранжевый', 'Бананы мини'],
#  ['Лимон оранжевый', 'Баклажаны грунтовые'],
#  ['Лимон оранжевый', 'Салат Романо'],
#  ['Лимон оранжевый', 'Яблоки Мутсу'],
#  ['Лимон оранжевый', 'Компотная смесь'],
#  ['Лимон оранжевый', 'Курага темно-оранжевая'],
#  ['Лимон оранжевый', 'Дыня цукаты'],
#  ['Лимон оранжевый', 'Миндаль жареный'],
#  ['Лимон оранжевый', 'Урюк сушеный'],
#  ['Лимон оранжевый', 'Лайм'],
#  ['Лимон оранжевый', 'Пекан очищенный'],
#  ['Лимон оранжевый', 'Салат Фриллис'],
#  ['Лимон оранжевый', 'Бананы'],
#  ['Лимон оранжевый', 'Салат Корн'],
#  ['Лимон оранжевый', 'Инжир сушеный'],
#  ['Лимон оранжевый', 'Инжир свежий'],
#  ['Лимон оранжевый', 'Груша вяленая'],
#  ['Лимон оранжевый', 'Салат Радичио'],
#  ['Лимон оранжевый', 'Кумкват сушеный'],
#  ['Лимон оранжевый', 'Персики армянские'],
#  ['Лимон оранжевый', 'Щавель'],
#  ['Лимон оранжевый', 'Огурцы длинноплодные'],
#  ['Лимон оранжевый', 'Малина садовая'],
#  ['Лимон оранжевый', 'Букет "Фаворит"'],
#  ['Лимон оранжевый', 'Семена льна'],
#  ['Лимон оранжевый', 'Базилик красный'],
#  ['Лимон оранжевый', 'Тыква'],
#  ['Лимон оранжевый', 'Сельдерей лист'],
#  ['Лимон оранжевый', 'Персики азербайджанские'],
#  ['Лимон оранжевый', 'Вишня вяленая'],
#  ['Лимон оранжевый', 'Миндаль сырой'],
#  ['Лимон оранжевый', 'Кабачки желтые'],
#  ['Лимон оранжевый', 'Яблоки Голден'],
#  ['Лимон оранжевый', 'Базилик зеленый'],
#  ['Лимон оранжевый', 'Фундук жареный'],
#  ['Лимон оранжевый', 'Кизил свежий'],
#  ['Лимон оранжевый', 'Боярышник сушеный'],
#  ['Лимон оранжевый', 'Огурцы Миринда'],
#  ['Лимон оранжевый', 'Букет "Брокколи"'],
#  ['Лимон оранжевый', 'Помидоры дагестанские'],
#  ['Лимон оранжевый', 'Салат Китайский'],
#  ['Лимон оранжевый', 'Груша Конференц'],
#  ['Лимон оранжевый', 'Огурцы Кураж'],
#  ['Лимон оранжевый', 'Фасоль стручковая'],
#  ['Лимон оранжевый', 'Цуккини'],
#  ['Лимон оранжевый', 'Мята'],
#  ['Лимон оранжевый', 'Кунжут белый'],
#  ['Лимон оранжевый', 'Слива красная'],
#  ['Лимон оранжевый', 'Букет "Кассиопея"'],
#  ['Лимон оранжевый', 'Салат Фризе'],
#  ['Лимон оранжевый', 'Барбарис сушеный'],
#  ['Лимон оранжевый', 'Шалфей'],
#  ['Лимон оранжевый', 'Манго зеленое'],
#  ['Лимон оранжевый', 'Открытка Love'],
#  ['Лимон оранжевый', 'Яблоки Джонаголд'],
#  ['Лимон оранжевый', 'Лук-шалот'],
#  ['Лимон оранжевый', 'Огурцы бакинские'],
#  ['Лимон оранжевый', 'Помело сушеное'],
#  ['Лимон оранжевый', 'Ананасовые кольца'],
#  ['Лимон оранжевый', 'Рамбутан'],
#  ['Лимон оранжевый', 'Кешью сырой'],
#  ['Лимон оранжевый', 'Яблоки Чемпион'],
#  ['Лимон оранжевый', 'Редис'],
#  ['Лимон оранжевый', 'Тамарилло'],
#  ['Лимон оранжевый', 'Капуста Савойская'],
#  ['Лимон оранжевый', 'Свекла'],
#  ['Лимон оранжевый', 'Грибы вешенки'],
#  ['Лимон оранжевый', 'Абрикос вяленый'],
#  ['Лимон оранжевый', 'Рычал-Су, 1л'],
#  ['Лимон оранжевый', 'Букет "Закат"'],
#  ['Лимон оранжевый', 'Дыня Колхозница'],
#  ['Лимон оранжевый', 'Тыква миндальная'],
#  ['Лимон оранжевый', 'Яблоки сушеные'],
#  ['Лимон оранжевый', 'Капуста белокочанная'],
#  ['Лимон оранжевый', 'Финики королевские'],
#  ['Лимон оранжевый', 'Банановые чипсы'],
#  ['Лимон оранжевый', 'Кокосовая стружка'],
#  ['Лимон оранжевый', 'Грибы шампиньоны'],
#  ['Лимон оранжевый', 'Фенхель свежий'],
#  ['Лимон оранжевый', 'Салат микс'],
#  ['Лимон оранжевый', 'Папайя сушеная'],
#  ['Лимон оранжевый', 'Манго цукаты'],
#  ['Лимон оранжевый', 'Папайя'],
#  ['Лимон оранжевый', 'Манго желтое'],
#  ['Лимон оранжевый', 'Нектарины'],
#  ['Лимон оранжевый', 'Ананас Gold'],
#  ['Лимон оранжевый', 'Картофель черри'],
#  ['Лимон оранжевый', 'Авокадо ХАСС'],
#  ['Лимон оранжевый', 'Цыпленок-корнишон замороженный'],
#  ['Лимон оранжевый', 'Арбуз овальный'],
#  ['Лимон оранжевый', 'Пастернак корень'],
#  ['Лимон оранжевый', 'Баклажаны белые'],
#  ['Лимон оранжевый', 'Букет "Оазис"'],
#  ['Лимон оранжевый', 'Брусника свежая'],
#  ['Лимон оранжевый', 'Кешью жареный'],
#  ['Лимон оранжевый', 'Букет "Колорит"'],
#  ['Лимон оранжевый', 'Курага'],
#  ['Лимон оранжевый', 'Миндальные лепестки'],
#  ['Лимон оранжевый', 'Лонган'],
#  ['Лимон оранжевый', 'Розмарин'],
#  ['Лимон оранжевый', 'Грибы Еринги'],
#  ['Лимон оранжевый', 'Слива азербайджанская'],
#  ['Лимон оранжевый', 'Имбирь корень'],
#  ['Лимон оранжевый', 'Тимьян (чабрец)'],
#  ['Лимон оранжевый', 'Крыжовник свежий'],
#  ['Лимон оранжевый', 'Кролик фермерский'],
#  ['Лимон оранжевый', 'Шиповник'],
#  ['Лимон оранжевый', 'Грейпфрут красный'],
#  ['Лимон оранжевый', 'Изюм Малаяр'],
#  ['Лимон оранжевый', 'Букет "Оранж"'],
#  ['Лимон оранжевый', 'Салат Московский'],
#  ['Лимон оранжевый', 'Алыча вяленая'],
#  ['Лимон оранжевый', 'Кунжут черный'],
#  ['Лимон оранжевый', 'Облепиха'],
#  ['Лимон оранжевый', 'Пленка пищевая'],
#  ['Лимон оранжевый', 'Клубника сушеная'],
#  ['Лимон оранжевый', 'Лук-резанец (шнитт-лук)'],
#  ['Лимон оранжевый', 'Цукаты (шайбы)'],
#  ['Лимон оранжевый', 'Киви'],
#  ['Лимон оранжевый', 'Тархун (эстрагон)'],
#  ['Лимон оранжевый', 'Яблоки сезонные'],
#  ['Лимон оранжевый', 'Ежевика свежая'],
#  ['Лимон оранжевый', 'Цукаты (лепестки)'],
#  ['Лимон оранжевый', 'Семена Чиа'],
#  ['Лимон оранжевый', 'Салат Латук'],
#  ['Лимон оранжевый', 'Маракуйя'],
#  ['Лимон оранжевый', 'Мак пищевой'],
#  ['Лимон оранжевый', 'Кумкват свежий'],
#  ['Лимон оранжевый', 'Дыня "Косичка"'],
#  ['Лимон оранжевый', 'Физалис'],
#  ['Лимон оранжевый', 'Яблоки Фуджи'],
#  ['Лимон оранжевый', 'Фундук сырой'],
#  ['Лимон оранжевый', 'Помело'],
#  ['Лимон оранжевый', 'Капуста краснокочанная'],
#  ['Лимон оранжевый', 'Лемонграсс'],
#  ['Лимон оранжевый', 'Авокадо стандарт'],
#  ['Лимон оранжевый', 'Малина сушеная'],
#  ['Лук-порей', 'Лук репчатый'],
#  ['Лук-порей', 'Малина свежая'],
#  ['Лук-порей', 'Морковь немытая'],
#  ['Лук-порей', 'Черешня сушеная'],
#  ['Лук-порей', 'Изюм Султана'],
#  ['Лук-порей', 'Капуста цветная'],
#  ['Лук-порей', 'Бразильский орех'],
#  ['Лук-порей', 'Дыня Гуляби'],
#  ['Лук-порей', 'Шпинат мини'],
#  ['Лук-порей', 'Изюм Голд'],
#  ['Лук-порей', 'Огурцы Луховицкие'],
#  ['Лук-порей', 'Чеснок весовой'],
#  ['Лук-порей', 'Огурцы Белоруссия'],
#  ['Лук-порей', 'Черешня отборная'],
#  ['Лук-порей', 'Абрикосы молдавские'],
#  ['Лук-порей', 'Кукуруза мини'],
#  ['Лук-порей', 'Грибы лисички'],
#  ['Лук-порей', 'Слива Президент'],
#  ['Лук-порей', 'Апельсины столовые'],
#  ['Лук-порей', 'Кукуруза свежая'],
#  ['Лук-порей', 'Салат Руккола'],
#  ['Лук-порей', 'Гранат'],
#  ['Лук-порей', 'Подпись открытки'],
#  ['Лук-порей', 'Лук зеленый'],
#  ['Лук-порей', 'Цукаты (брусочки)'],
#  ['Лук-порей', 'Кокос питьевой'],
#  ['Лук-порей', 'Петрушка'],
#  ['Лук-порей', 'Помидоры Парадайз'],
#  ['Лук-порей', 'Ягоды Годжи'],
#  ['Лук-порей', 'Укроп'],
#  ['Лук-порей', 'Черника свежая'],
#  ['Лук-порей', 'Персики'],
#  ['Лук-порей', 'Арбуз'],
#  ['Лук-порей', 'Салат Айсберг'],
#  ['Лук-порей', 'Галангал корень'],
#  ['Лук-порей', 'Петрушка Кудрявая'],
#  ['Лук-порей', 'Яблоки Гала'],
#  ['Лук-порей', 'Курага коричневая'],
#  ['Лук-порей', 'Горох стручковый'],
#  ['Лук-порей', 'Персики узбекские'],
#  ['Лук-порей', 'Персик сушеный'],
#  ['Лук-порей', 'Груша Форел'],
#  ['Лук-порей', 'Яблоки Айдаред'],
#  ['Лук-порей', 'Яблоки Симиренко'],
#  ['Лук-порей', 'Кабачки'],
#  ['Лук-порей', 'Кинза'],
#  ['Лук-порей', 'Морковь мытая'],
#  ['Лук-порей', 'Капуста Кольраби'],
#  ['Лук-порей', 'Груша Аббат'],
#  ['Лук-порей', 'Шпинат'],
#  ['Лук-порей', 'Вишня садовая'],
#  ['Лук-порей', 'Сахар-песок, 5кг'],
#  ['Лук-порей', 'Сельдерей корень'],
#  ['Лук-порей', 'Груша Пакхам'],
#  ['Лук-порей', 'Чеснок молодой'],
#  ['Лук-порей', 'Мандарины'],
#  ['Лук-порей', 'Мангостин свежий'],
#  ['Лук-порей', 'Груша садовая'],
#  ['Лук-порей', 'Помидоры черри'],
#  ['Лук-порей', 'Бананы мини'],
#  ['Лук-порей', 'Баклажаны грунтовые'],
#  ['Лук-порей', 'Салат Романо'],
#  ['Лук-порей', 'Яблоки Мутсу'],
#  ['Лук-порей', 'Компотная смесь'],
#  ['Лук-порей', 'Курага темно-оранжевая'],
#  ['Лук-порей', 'Дыня цукаты'],
#  ['Лук-порей', 'Миндаль жареный'],
#  ['Лук-порей', 'Урюк сушеный'],
#  ['Лук-порей', 'Лайм'],
#  ['Лук-порей', 'Пекан очищенный'],
#  ['Лук-порей', 'Салат Фриллис'],
#  ['Лук-порей', 'Бананы'],
#  ['Лук-порей', 'Салат Корн'],
#  ['Лук-порей', 'Инжир сушеный'],
#  ['Лук-порей', 'Инжир свежий'],
#  ['Лук-порей', 'Груша вяленая'],
#  ['Лук-порей', 'Салат Радичио'],
#  ['Лук-порей', 'Кумкват сушеный'],
#  ['Лук-порей', 'Персики армянские'],
#  ['Лук-порей', 'Щавель'],
#  ['Лук-порей', 'Огурцы длинноплодные'],
#  ['Лук-порей', 'Малина садовая'],
#  ['Лук-порей', 'Букет "Фаворит"'],
#  ['Лук-порей', 'Семена льна'],
#  ['Лук-порей', 'Базилик красный'],
#  ['Лук-порей', 'Тыква'],
#  ['Лук-порей', 'Сельдерей лист'],
#  ['Лук-порей', 'Персики азербайджанские'],
#  ['Лук-порей', 'Вишня вяленая'],
#  ['Лук-порей', 'Миндаль сырой'],
#  ['Лук-порей', 'Кабачки желтые'],
#  ['Лук-порей', 'Яблоки Голден'],
#  ['Лук-порей', 'Базилик зеленый'],
#  ['Лук-порей', 'Фундук жареный'],
#  ['Лук-порей', 'Кизил свежий'],
#  ['Лук-порей', 'Боярышник сушеный'],
#  ['Лук-порей', 'Огурцы Миринда'],
#  ['Лук-порей', 'Букет "Брокколи"'],
#  ['Лук-порей', 'Помидоры дагестанские'],
#  ['Лук-порей', 'Салат Китайский'],
#  ['Лук-порей', 'Груша Конференц'],
#  ['Лук-порей', 'Огурцы Кураж'],
#  ['Лук-порей', 'Фасоль стручковая'],
#  ['Лук-порей', 'Цуккини'],
#  ['Лук-порей', 'Мята'],
#  ['Лук-порей', 'Кунжут белый'],
#  ['Лук-порей', 'Слива красная'],
#  ['Лук-порей', 'Букет "Кассиопея"'],
#  ['Лук-порей', 'Салат Фризе'],
#  ['Лук-порей', 'Барбарис сушеный'],
#  ['Лук-порей', 'Шалфей'],
#  ['Лук-порей', 'Манго зеленое'],
#  ['Лук-порей', 'Открытка Love'],
#  ['Лук-порей', 'Яблоки Джонаголд'],
#  ['Лук-порей', 'Лук-шалот'],
#  ['Лук-порей', 'Огурцы бакинские'],
#  ['Лук-порей', 'Помело сушеное'],
#  ['Лук-порей', 'Ананасовые кольца'],
#  ['Лук-порей', 'Рамбутан'],
#  ['Лук-порей', 'Кешью сырой'],
#  ['Лук-порей', 'Яблоки Чемпион'],
#  ['Лук-порей', 'Редис'],
#  ['Лук-порей', 'Тамарилло'],
#  ['Лук-порей', 'Капуста Савойская'],
#  ['Лук-порей', 'Свекла'],
#  ['Лук-порей', 'Грибы вешенки'],
#  ['Лук-порей', 'Абрикос вяленый'],
#  ['Лук-порей', 'Рычал-Су, 1л'],
#  ['Лук-порей', 'Букет "Закат"'],
#  ['Лук-порей', 'Дыня Колхозница'],
#  ['Лук-порей', 'Тыква миндальная'],
#  ['Лук-порей', 'Яблоки сушеные'],
#  ['Лук-порей', 'Капуста белокочанная'],
#  ['Лук-порей', 'Финики королевские'],
#  ['Лук-порей', 'Банановые чипсы'],
#  ['Лук-порей', 'Кокосовая стружка'],
#  ['Лук-порей', 'Грибы шампиньоны'],
#  ['Лук-порей', 'Фенхель свежий'],
#  ['Лук-порей', 'Салат микс'],
#  ['Лук-порей', 'Папайя сушеная'],
#  ['Лук-порей', 'Манго цукаты'],
#  ['Лук-порей', 'Папайя'],
#  ['Лук-порей', 'Манго желтое'],
#  ['Лук-порей', 'Нектарины'],
#  ['Лук-порей', 'Ананас Gold'],
#  ['Лук-порей', 'Картофель черри'],
#  ['Лук-порей', 'Авокадо ХАСС'],
#  ['Лук-порей', 'Цыпленок-корнишон замороженный'],
#  ['Лук-порей', 'Арбуз овальный'],
#  ['Лук-порей', 'Пастернак корень'],
#  ['Лук-порей', 'Баклажаны белые'],
#  ['Лук-порей', 'Букет "Оазис"'],
#  ['Лук-порей', 'Брусника свежая'],
#  ['Лук-порей', 'Кешью жареный'],
#  ['Лук-порей', 'Букет "Колорит"'],
#  ['Лук-порей', 'Курага'],
#  ['Лук-порей', 'Миндальные лепестки'],
#  ['Лук-порей', 'Лонган'],
#  ['Лук-порей', 'Розмарин'],
#  ['Лук-порей', 'Грибы Еринги'],
#  ['Лук-порей', 'Слива азербайджанская'],
#  ['Лук-порей', 'Имбирь корень'],
#  ['Лук-порей', 'Тимьян (чабрец)'],
#  ['Лук-порей', 'Крыжовник свежий'],
#  ['Лук-порей', 'Кролик фермерский'],
#  ['Лук-порей', 'Шиповник'],
#  ['Лук-порей', 'Грейпфрут красный'],
#  ['Лук-порей', 'Изюм Малаяр'],
#  ['Лук-порей', 'Букет "Оранж"'],
#  ['Лук-порей', 'Салат Московский'],
#  ['Лук-порей', 'Алыча вяленая'],
#  ['Лук-порей', 'Кунжут черный'],
#  ['Лук-порей', 'Облепиха'],
#  ['Лук-порей', 'Пленка пищевая'],
#  ['Лук-порей', 'Клубника сушеная'],
#  ['Лук-порей', 'Лук-резанец (шнитт-лук)'],
#  ['Лук-порей', 'Цукаты (шайбы)'],
#  ['Лук-порей', 'Киви'],
#  ['Лук-порей', 'Тархун (эстрагон)'],
#  ['Лук-порей', 'Яблоки сезонные'],
#  ['Лук-порей', 'Ежевика свежая'],
#  ['Лук-порей', 'Цукаты (лепестки)'],
#  ['Лук-порей', 'Семена Чиа'],
#  ['Лук-порей', 'Салат Латук'],
#  ['Лук-порей', 'Маракуйя'],
#  ['Лук-порей', 'Мак пищевой'],
#  ['Лук-порей', 'Кумкват свежий'],
#  ['Лук-порей', 'Дыня "Косичка"'],
#  ['Лук-порей', 'Физалис'],
#  ['Лук-порей', 'Яблоки Фуджи'],
#  ['Лук-порей', 'Фундук сырой'],
#  ['Лук-порей', 'Помело'],
#  ['Лук-порей', 'Капуста краснокочанная'],
#  ['Лук-порей', 'Лемонграсс'],
#  ['Лук-порей', 'Авокадо стандарт'],
#  ['Лук-порей', 'Малина сушеная'],
#  ['Лук репчатый', 'Малина свежая'],
#  ['Лук репчатый', 'Морковь немытая'],
#  ['Лук репчатый', 'Черешня сушеная'],
#  ['Лук репчатый', 'Изюм Султана'],
#  ['Лук репчатый', 'Капуста цветная'],
#  ['Лук репчатый', 'Бразильский орех'],
#  ['Лук репчатый', 'Дыня Гуляби'],
#  ['Лук репчатый', 'Шпинат мини'],
#  ['Лук репчатый', 'Изюм Голд'],
#  ['Лук репчатый', 'Огурцы Луховицкие'],
#  ['Лук репчатый', 'Чеснок весовой'],
#  ['Лук репчатый', 'Огурцы Белоруссия'],
#  ['Лук репчатый', 'Черешня отборная'],
#  ['Лук репчатый', 'Абрикосы молдавские'],
#  ['Лук репчатый', 'Кукуруза мини'],
#  ['Лук репчатый', 'Грибы лисички'],
#  ['Лук репчатый', 'Слива Президент'],
#  ['Лук репчатый', 'Апельсины столовые'],
#  ['Лук репчатый', 'Кукуруза свежая'],
#  ['Лук репчатый', 'Салат Руккола'],
#  ['Лук репчатый', 'Гранат'],
#  ['Лук репчатый', 'Подпись открытки'],
#  ['Лук репчатый', 'Лук зеленый'],
#  ['Лук репчатый', 'Цукаты (брусочки)'],
#  ['Лук репчатый', 'Кокос питьевой'],
#  ['Лук репчатый', 'Петрушка'],
#  ['Лук репчатый', 'Помидоры Парадайз'],
#  ['Лук репчатый', 'Ягоды Годжи'],
#  ['Лук репчатый', 'Укроп'],
#  ['Лук репчатый', 'Черника свежая'],
#  ['Лук репчатый', 'Персики'],
#  ['Лук репчатый', 'Арбуз'],
#  ['Лук репчатый', 'Салат Айсберг'],
#  ['Лук репчатый', 'Галангал корень'],
#  ['Лук репчатый', 'Петрушка Кудрявая'],
#  ['Лук репчатый', 'Яблоки Гала'],
#  ['Лук репчатый', 'Курага коричневая'],
#  ['Лук репчатый', 'Горох стручковый'],
#  ['Лук репчатый', 'Персики узбекские'],
#  ['Лук репчатый', 'Персик сушеный'],
#  ['Лук репчатый', 'Груша Форел'],
#  ['Лук репчатый', 'Яблоки Айдаред'],
#  ['Лук репчатый', 'Яблоки Симиренко'],
#  ['Лук репчатый', 'Кабачки'],
#  ['Лук репчатый', 'Кинза'],
#  ['Лук репчатый', 'Морковь мытая'],
#  ['Лук репчатый', 'Капуста Кольраби'],
#  ['Лук репчатый', 'Груша Аббат'],
#  ['Лук репчатый', 'Шпинат'],
#  ['Лук репчатый', 'Вишня садовая'],
#  ['Лук репчатый', 'Сахар-песок, 5кг'],
#  ['Лук репчатый', 'Сельдерей корень'],
#  ['Лук репчатый', 'Груша Пакхам'],
#  ['Лук репчатый', 'Чеснок молодой'],
#  ['Лук репчатый', 'Мандарины'],
#  ['Лук репчатый', 'Мангостин свежий'],
#  ['Лук репчатый', 'Груша садовая'],
#  ['Лук репчатый', 'Помидоры черри'],
#  ['Лук репчатый', 'Бананы мини'],
#  ['Лук репчатый', 'Баклажаны грунтовые'],
#  ['Лук репчатый', 'Салат Романо'],
#  ['Лук репчатый', 'Яблоки Мутсу'],
#  ['Лук репчатый', 'Компотная смесь'],
#  ['Лук репчатый', 'Курага темно-оранжевая'],
#  ['Лук репчатый', 'Дыня цукаты'],
#  ['Лук репчатый', 'Миндаль жареный'],
#  ['Лук репчатый', 'Урюк сушеный'],
#  ['Лук репчатый', 'Лайм'],
#  ['Лук репчатый', 'Пекан очищенный'],
#  ['Лук репчатый', 'Салат Фриллис'],
#  ['Лук репчатый', 'Бананы'],
#  ['Лук репчатый', 'Салат Корн'],
#  ['Лук репчатый', 'Инжир сушеный'],
#  ['Лук репчатый', 'Инжир свежий'],
#  ['Лук репчатый', 'Груша вяленая'],
#  ['Лук репчатый', 'Салат Радичио'],
#  ['Лук репчатый', 'Кумкват сушеный'],
#  ['Лук репчатый', 'Персики армянские'],
#  ['Лук репчатый', 'Щавель'],
#  ['Лук репчатый', 'Огурцы длинноплодные'],
#  ['Лук репчатый', 'Малина садовая'],
#  ['Лук репчатый', 'Букет "Фаворит"'],
#  ['Лук репчатый', 'Семена льна'],
#  ['Лук репчатый', 'Базилик красный'],
#  ['Лук репчатый', 'Тыква'],
#  ['Лук репчатый', 'Сельдерей лист'],
#  ['Лук репчатый', 'Персики азербайджанские'],
#  ['Лук репчатый', 'Вишня вяленая'],
#  ['Лук репчатый', 'Миндаль сырой'],
#  ['Лук репчатый', 'Кабачки желтые'],
#  ['Лук репчатый', 'Яблоки Голден'],
#  ['Лук репчатый', 'Базилик зеленый'],
#  ['Лук репчатый', 'Фундук жареный'],
#  ['Лук репчатый', 'Кизил свежий'],
#  ['Лук репчатый', 'Боярышник сушеный'],
#  ['Лук репчатый', 'Огурцы Миринда'],
#  ['Лук репчатый', 'Букет "Брокколи"'],
#  ['Лук репчатый', 'Помидоры дагестанские'],
#  ['Лук репчатый', 'Салат Китайский'],
#  ['Лук репчатый', 'Груша Конференц'],
#  ['Лук репчатый', 'Огурцы Кураж'],
#  ['Лук репчатый', 'Фасоль стручковая'],
#  ['Лук репчатый', 'Цуккини'],
#  ['Лук репчатый', 'Мята'],
#  ['Лук репчатый', 'Кунжут белый'],
#  ['Лук репчатый', 'Слива красная'],
#  ['Лук репчатый', 'Букет "Кассиопея"'],
#  ['Лук репчатый', 'Салат Фризе'],
#  ['Лук репчатый', 'Барбарис сушеный'],
#  ['Лук репчатый', 'Шалфей'],
#  ['Лук репчатый', 'Манго зеленое'],
#  ['Лук репчатый', 'Открытка Love'],
#  ['Лук репчатый', 'Яблоки Джонаголд'],
#  ['Лук репчатый', 'Лук-шалот'],
#  ['Лук репчатый', 'Огурцы бакинские'],
#  ['Лук репчатый', 'Помело сушеное'],
#  ['Лук репчатый', 'Ананасовые кольца'],
#  ['Лук репчатый', 'Рамбутан'],
#  ['Лук репчатый', 'Кешью сырой'],
#  ['Лук репчатый', 'Яблоки Чемпион'],
#  ['Лук репчатый', 'Редис'],
#  ['Лук репчатый', 'Тамарилло'],
#  ['Лук репчатый', 'Капуста Савойская'],
#  ['Лук репчатый', 'Свекла'],
#  ['Лук репчатый', 'Грибы вешенки'],
#  ['Лук репчатый', 'Абрикос вяленый'],
#  ['Лук репчатый', 'Рычал-Су, 1л'],
#  ['Лук репчатый', 'Букет "Закат"'],
#  ['Лук репчатый', 'Дыня Колхозница'],
#  ['Лук репчатый', 'Тыква миндальная'],
#  ['Лук репчатый', 'Яблоки сушеные'],
#  ['Лук репчатый', 'Капуста белокочанная'],
#  ['Лук репчатый', 'Финики королевские'],
#  ['Лук репчатый', 'Банановые чипсы'],
#  ['Лук репчатый', 'Кокосовая стружка'],
#  ['Лук репчатый', 'Грибы шампиньоны'],
#  ['Лук репчатый', 'Фенхель свежий'],
#  ['Лук репчатый', 'Салат микс'],
#  ['Лук репчатый', 'Папайя сушеная'],
#  ['Лук репчатый', 'Манго цукаты'],
#  ['Лук репчатый', 'Папайя'],
#  ['Лук репчатый', 'Манго желтое'],
#  ['Лук репчатый', 'Нектарины'],
#  ['Лук репчатый', 'Ананас Gold'],
#  ['Лук репчатый', 'Картофель черри'],
#  ['Лук репчатый', 'Авокадо ХАСС'],
#  ['Лук репчатый', 'Цыпленок-корнишон замороженный'],
#  ['Лук репчатый', 'Арбуз овальный'],
#  ['Лук репчатый', 'Пастернак корень'],
#  ['Лук репчатый', 'Баклажаны белые'],
#  ['Лук репчатый', 'Букет "Оазис"'],
#  ['Лук репчатый', 'Брусника свежая'],
#  ['Лук репчатый', 'Кешью жареный'],
#  ['Лук репчатый', 'Букет "Колорит"'],
#  ['Лук репчатый', 'Курага'],
#  ['Лук репчатый', 'Миндальные лепестки'],
#  ['Лук репчатый', 'Лонган'],
#  ['Лук репчатый', 'Розмарин'],
#  ['Лук репчатый', 'Грибы Еринги'],
#  ['Лук репчатый', 'Слива азербайджанская'],
#  ['Лук репчатый', 'Имбирь корень'],
#  ['Лук репчатый', 'Тимьян (чабрец)'],
#  ['Лук репчатый', 'Крыжовник свежий'],
#  ['Лук репчатый', 'Кролик фермерский'],
#  ['Лук репчатый', 'Шиповник'],
#  ['Лук репчатый', 'Грейпфрут красный'],
#  ['Лук репчатый', 'Изюм Малаяр'],
#  ['Лук репчатый', 'Букет "Оранж"'],
#  ['Лук репчатый', 'Салат Московский'],
#  ['Лук репчатый', 'Алыча вяленая'],
#  ['Лук репчатый', 'Кунжут черный'],
#  ['Лук репчатый', 'Облепиха'],
#  ['Лук репчатый', 'Пленка пищевая'],
#  ['Лук репчатый', 'Клубника сушеная'],
#  ['Лук репчатый', 'Лук-резанец (шнитт-лук)'],
#  ['Лук репчатый', 'Цукаты (шайбы)'],
#  ['Лук репчатый', 'Киви'],
#  ['Лук репчатый', 'Тархун (эстрагон)'],
#  ['Лук репчатый', 'Яблоки сезонные'],
#  ['Лук репчатый', 'Ежевика свежая'],
#  ['Лук репчатый', 'Цукаты (лепестки)'],
#  ['Лук репчатый', 'Семена Чиа'],
#  ['Лук репчатый', 'Салат Латук'],
#  ['Лук репчатый', 'Маракуйя'],
#  ['Лук репчатый', 'Мак пищевой'],
#  ['Лук репчатый', 'Кумкват свежий'],
#  ['Лук репчатый', 'Дыня "Косичка"'],
#  ['Лук репчатый', 'Физалис'],
#  ['Лук репчатый', 'Яблоки Фуджи'],
#  ['Лук репчатый', 'Фундук сырой'],
#  ['Лук репчатый', 'Помело'],
#  ['Лук репчатый', 'Капуста краснокочанная'],
#  ['Лук репчатый', 'Лемонграсс'],
#  ['Лук репчатый', 'Авокадо стандарт'],
#  ['Лук репчатый', 'Малина сушеная'],
#  ['Малина свежая', 'Морковь немытая'],
#  ['Малина свежая', 'Черешня сушеная'],
#  ['Малина свежая', 'Изюм Султана'],
#  ['Малина свежая', 'Капуста цветная'],
#  ['Малина свежая', 'Бразильский орех'],
#  ['Малина свежая', 'Дыня Гуляби'],
#  ['Малина свежая', 'Шпинат мини'],
#  ['Малина свежая', 'Изюм Голд'],
#  ['Малина свежая', 'Огурцы Луховицкие'],
#  ['Малина свежая', 'Чеснок весовой'],
#  ['Малина свежая', 'Огурцы Белоруссия'],
#  ['Малина свежая', 'Черешня отборная'],
#  ['Малина свежая', 'Абрикосы молдавские'],
#  ['Малина свежая', 'Кукуруза мини'],
#  ['Малина свежая', 'Грибы лисички'],
#  ['Малина свежая', 'Слива Президент'],
#  ['Малина свежая', 'Апельсины столовые'],
#  ['Малина свежая', 'Кукуруза свежая'],
#  ['Малина свежая', 'Салат Руккола'],
#  ['Малина свежая', 'Гранат'],
#  ['Малина свежая', 'Подпись открытки'],
#  ['Малина свежая', 'Лук зеленый'],
#  ['Малина свежая', 'Цукаты (брусочки)'],
#  ['Малина свежая', 'Кокос питьевой'],
#  ['Малина свежая', 'Петрушка'],
#  ['Малина свежая', 'Помидоры Парадайз'],
#  ['Малина свежая', 'Ягоды Годжи'],
#  ['Малина свежая', 'Укроп'],
#  ['Малина свежая', 'Черника свежая'],
#  ['Малина свежая', 'Персики'],
#  ['Малина свежая', 'Арбуз'],
#  ['Малина свежая', 'Салат Айсберг'],
#  ['Малина свежая', 'Галангал корень'],
#  ['Малина свежая', 'Петрушка Кудрявая'],
#  ['Малина свежая', 'Яблоки Гала'],
#  ['Малина свежая', 'Курага коричневая'],
#  ['Малина свежая', 'Горох стручковый'],
#  ['Малина свежая', 'Персики узбекские'],
#  ['Малина свежая', 'Персик сушеный'],
#  ['Малина свежая', 'Груша Форел'],
#  ['Малина свежая', 'Яблоки Айдаред'],
#  ['Малина свежая', 'Яблоки Симиренко'],
#  ['Малина свежая', 'Кабачки'],
#  ['Малина свежая', 'Кинза'],
#  ['Малина свежая', 'Морковь мытая'],
#  ['Малина свежая', 'Капуста Кольраби'],
#  ['Малина свежая', 'Груша Аббат'],
#  ['Малина свежая', 'Шпинат'],
#  ['Малина свежая', 'Вишня садовая'],
#  ['Малина свежая', 'Сахар-песок, 5кг'],
#  ['Малина свежая', 'Сельдерей корень'],
#  ['Малина свежая', 'Груша Пакхам'],
#  ['Малина свежая', 'Чеснок молодой'],
#  ['Малина свежая', 'Мандарины'],
#  ['Малина свежая', 'Мангостин свежий'],
#  ['Малина свежая', 'Груша садовая'],
#  ['Малина свежая', 'Помидоры черри'],
#  ['Малина свежая', 'Бананы мини'],
#  ['Малина свежая', 'Баклажаны грунтовые'],
#  ['Малина свежая', 'Салат Романо'],
#  ['Малина свежая', 'Яблоки Мутсу'],
#  ['Малина свежая', 'Компотная смесь'],
#  ['Малина свежая', 'Курага темно-оранжевая'],
#  ['Малина свежая', 'Дыня цукаты'],
#  ['Малина свежая', 'Миндаль жареный'],
#  ['Малина свежая', 'Урюк сушеный'],
#  ['Малина свежая', 'Лайм'],
#  ['Малина свежая', 'Пекан очищенный'],
#  ['Малина свежая', 'Салат Фриллис'],
#  ['Малина свежая', 'Бананы'],
#  ['Малина свежая', 'Салат Корн'],
#  ['Малина свежая', 'Инжир сушеный'],
#  ['Малина свежая', 'Инжир свежий'],
#  ['Малина свежая', 'Груша вяленая'],
#  ['Малина свежая', 'Салат Радичио'],
#  ['Малина свежая', 'Кумкват сушеный'],
#  ['Малина свежая', 'Персики армянские'],
#  ['Малина свежая', 'Щавель'],
#  ['Малина свежая', 'Огурцы длинноплодные'],
#  ['Малина свежая', 'Малина садовая'],
#  ['Малина свежая', 'Букет "Фаворит"'],
#  ['Малина свежая', 'Семена льна'],
#  ['Малина свежая', 'Базилик красный'],
#  ['Малина свежая', 'Тыква'],
#  ['Малина свежая', 'Сельдерей лист'],
#  ['Малина свежая', 'Персики азербайджанские'],
#  ['Малина свежая', 'Вишня вяленая'],
#  ['Малина свежая', 'Миндаль сырой'],
#  ['Малина свежая', 'Кабачки желтые'],
#  ['Малина свежая', 'Яблоки Голден'],
#  ['Малина свежая', 'Базилик зеленый'],
#  ['Малина свежая', 'Фундук жареный'],
#  ['Малина свежая', 'Кизил свежий'],
#  ['Малина свежая', 'Боярышник сушеный'],
#  ['Малина свежая', 'Огурцы Миринда'],
#  ['Малина свежая', 'Букет "Брокколи"'],
#  ['Малина свежая', 'Помидоры дагестанские'],
#  ['Малина свежая', 'Салат Китайский'],
#  ['Малина свежая', 'Груша Конференц'],
#  ['Малина свежая', 'Огурцы Кураж'],
#  ['Малина свежая', 'Фасоль стручковая'],
#  ['Малина свежая', 'Цуккини'],
#  ['Малина свежая', 'Мята'],
#  ['Малина свежая', 'Кунжут белый'],
#  ['Малина свежая', 'Слива красная'],
#  ['Малина свежая', 'Букет "Кассиопея"'],
#  ['Малина свежая', 'Салат Фризе'],
#  ['Малина свежая', 'Барбарис сушеный'],
#  ['Малина свежая', 'Шалфей'],
#  ['Малина свежая', 'Манго зеленое'],
#  ['Малина свежая', 'Открытка Love'],
#  ['Малина свежая', 'Яблоки Джонаголд'],
#  ['Малина свежая', 'Лук-шалот'],
#  ['Малина свежая', 'Огурцы бакинские'],
#  ['Малина свежая', 'Помело сушеное'],
#  ['Малина свежая', 'Ананасовые кольца'],
#  ['Малина свежая', 'Рамбутан'],
#  ['Малина свежая', 'Кешью сырой'],
#  ['Малина свежая', 'Яблоки Чемпион'],
#  ['Малина свежая', 'Редис'],
#  ['Малина свежая', 'Тамарилло'],
#  ['Малина свежая', 'Капуста Савойская'],
#  ['Малина свежая', 'Свекла'],
#  ['Малина свежая', 'Грибы вешенки'],
#  ['Малина свежая', 'Абрикос вяленый'],
#  ['Малина свежая', 'Рычал-Су, 1л'],
#  ['Малина свежая', 'Букет "Закат"'],
#  ['Малина свежая', 'Дыня Колхозница'],
#  ['Малина свежая', 'Тыква миндальная'],
#  ['Малина свежая', 'Яблоки сушеные'],
#  ['Малина свежая', 'Капуста белокочанная'],
#  ['Малина свежая', 'Финики королевские'],
#  ['Малина свежая', 'Банановые чипсы'],
#  ['Малина свежая', 'Кокосовая стружка'],
#  ['Малина свежая', 'Грибы шампиньоны'],
#  ['Малина свежая', 'Фенхель свежий'],
#  ['Малина свежая', 'Салат микс'],
#  ['Малина свежая', 'Папайя сушеная'],
#  ['Малина свежая', 'Манго цукаты'],
#  ['Малина свежая', 'Папайя'],
#  ['Малина свежая', 'Манго желтое'],
#  ['Малина свежая', 'Нектарины'],
#  ['Малина свежая', 'Ананас Gold'],
#  ['Малина свежая', 'Картофель черри'],
#  ['Малина свежая', 'Авокадо ХАСС'],
#  ['Малина свежая', 'Цыпленок-корнишон замороженный'],
#  ['Малина свежая', 'Арбуз овальный'],
#  ['Малина свежая', 'Пастернак корень'],
#  ['Малина свежая', 'Баклажаны белые'],
#  ['Малина свежая', 'Букет "Оазис"'],
#  ['Малина свежая', 'Брусника свежая'],
#  ['Малина свежая', 'Кешью жареный'],
#  ['Малина свежая', 'Букет "Колорит"'],
#  ['Малина свежая', 'Курага'],
#  ['Малина свежая', 'Миндальные лепестки'],
#  ['Малина свежая', 'Лонган'],
#  ['Малина свежая', 'Розмарин'],
#  ['Малина свежая', 'Грибы Еринги'],
#  ['Малина свежая', 'Слива азербайджанская'],
#  ['Малина свежая', 'Имбирь корень'],
#  ['Малина свежая', 'Тимьян (чабрец)'],
#  ['Малина свежая', 'Крыжовник свежий'],
#  ['Малина свежая', 'Кролик фермерский'],
#  ['Малина свежая', 'Шиповник'],
#  ['Малина свежая', 'Грейпфрут красный'],
#  ['Малина свежая', 'Изюм Малаяр'],
#  ['Малина свежая', 'Букет "Оранж"'],
#  ['Малина свежая', 'Салат Московский'],
#  ['Малина свежая', 'Алыча вяленая'],
#  ['Малина свежая', 'Кунжут черный'],
#  ['Малина свежая', 'Облепиха'],
#  ['Малина свежая', 'Пленка пищевая'],
#  ['Малина свежая', 'Клубника сушеная'],
#  ['Малина свежая', 'Лук-резанец (шнитт-лук)'],
#  ['Малина свежая', 'Цукаты (шайбы)'],
#  ['Малина свежая', 'Киви'],
#  ['Малина свежая', 'Тархун (эстрагон)'],
#  ['Малина свежая', 'Яблоки сезонные'],
#  ['Малина свежая', 'Ежевика свежая'],
#  ['Малина свежая', 'Цукаты (лепестки)'],
#  ['Малина свежая', 'Семена Чиа'],
#  ['Малина свежая', 'Салат Латук'],
#  ['Малина свежая', 'Маракуйя'],
#  ['Малина свежая', 'Мак пищевой'],
#  ['Малина свежая', 'Кумкват свежий'],
#  ['Малина свежая', 'Дыня "Косичка"'],
#  ['Малина свежая', 'Физалис'],
#  ['Малина свежая', 'Яблоки Фуджи'],
#  ['Малина свежая', 'Фундук сырой'],
#  ['Малина свежая', 'Помело'],
#  ['Малина свежая', 'Капуста краснокочанная'],
#  ['Малина свежая', 'Лемонграсс'],
#  ['Малина свежая', 'Авокадо стандарт'],
#  ['Малина свежая', 'Малина сушеная'],
#  ['Морковь немытая', 'Черешня сушеная'],
#  ['Морковь немытая', 'Изюм Султана'],
#  ['Морковь немытая', 'Капуста цветная'],
#  ['Морковь немытая', 'Бразильский орех'],
#  ['Морковь немытая', 'Дыня Гуляби'],
#  ['Морковь немытая', 'Шпинат мини'],
#  ['Морковь немытая', 'Изюм Голд'],
#  ['Морковь немытая', 'Огурцы Луховицкие'],
#  ['Морковь немытая', 'Чеснок весовой'],
#  ['Морковь немытая', 'Огурцы Белоруссия'],
#  ['Морковь немытая', 'Черешня отборная'],
#  ['Морковь немытая', 'Абрикосы молдавские'],
#  ['Морковь немытая', 'Кукуруза мини'],
#  ['Морковь немытая', 'Грибы лисички'],
#  ['Морковь немытая', 'Слива Президент'],
#  ['Морковь немытая', 'Апельсины столовые'],
#  ['Морковь немытая', 'Кукуруза свежая'],
#  ['Морковь немытая', 'Салат Руккола'],
#  ['Морковь немытая', 'Гранат'],
#  ['Морковь немытая', 'Подпись открытки'],
#  ...]

# %%
# Число пар в списке должно быть равно числу сочетаний из n по k, где n - кол-во товаров, k = 2:
len(pairs) == scipy.special.comb(data['Товар'].nunique(), 2)
# Out:
# True

# %% [markdown]
# Другими словами, из 199 имеющихся товаров мы составили $199! / (2! * (199-2)!) = 198 * 199 / 2 = 19 701$ всех возможных пар, чтобы далее посчитать, как часто каждая из них встречается в покупках.

# %%
# Преобразуем данные так, чтобы получить для каждой покупки весь список товаров:

data1 = data.groupby('id')['Товар'].apply(list).to_frame()
data1
# Out:
#                                                     Товар
# id
# 17119   [Лимон, Лимон оранжевый, Лук-порей, Лук репчат...
# 17530   [Лимон оранжевый, Изюм Султана, Капуста цветна...
# 17618   [Абрикосы молдавские, Кукуруза мини, Грибы лис...
# 17724   [Абрикосы молдавские, Арбуз, Салат Айсберг, Га...
# 17814   [Арбуз, Кабачки, Кинза, Малина свежая, Морковь...
# ...                                                   ...
# 119062  [Баклажаны грунтовые, Персики, Персики армянск...
# 119110  [Авокадо ХАСС, Апельсины столовые, Базилик зел...
# 119206  [Огурцы длинноплодные, Грибы шампиньоны, Подпи...
# 119393  [Петрушка, Грибы Еринги, Инжир свежий, Редис, ...
# 119396  [Фасоль стручковая, Лук-резанец (шнитт-лук), Л...
#
# [3273 rows x 1 columns]

# %%
freq = []

# Для каждого списка-пары товаров посмотрим, является ли он подмножеством множества товаров в каждой покупке, и посчитаем
# сумму таких подмножеств для всех покупок:
for i in tqdm(pairs):
    freq.append({'1_Товар':i[0],'2_Товар':i[1],'Встречаемость':data1['Товар'].apply(lambda x: set(x) >= set(i)).sum()})
    
# Теперь добавим все данные в датафрейм:    
data3 = pd.DataFrame(freq)
data3 = data3.sort_values('Встречаемость', ascending = False)
data3.head(30)

# Получаем датафрейм со встречаемостью для всех возможных пар продуктов:
# Out:
# HBox(children=(FloatProgress(value=0.0, max=19701.0), HTML(value='')))
#                 1_Товар                  2_Товар  Встречаемость
# 2514  Огурцы Луховицкие                    Укроп            431
# 5338           Петрушка                    Укроп            408
# 2517  Огурцы Луховицкие                    Арбуз            345
# 2529  Огурцы Луховицкие                  Кабачки            326
# 5855              Укроп                    Кинза            303
# 4828        Лук зеленый                    Укроп            300
# 2511  Огурцы Луховицкие                 Петрушка            286
# 600        Лук репчатый        Огурцы Луховицкие            285
# 8240            Кабачки      Баклажаны грунтовые            284
# 5854              Укроп                  Кабачки            281
# 2545  Огурцы Луховицкие      Баклажаны грунтовые            276
# 5842              Укроп                    Арбуз            274
# 619        Лук репчатый                    Укроп            272
# 2512  Огурцы Луховицкие        Помидоры Парадайз            266
# 5870              Укроп      Баклажаны грунтовые            265
# 2556  Огурцы Луховицкие                   Бананы            264
# 2530  Огурцы Луховицкие                    Кинза            249
# 2572  Огурцы Луховицкие  Персики азербайджанские            244
# 5881              Укроп                   Бананы            239
# 6373              Арбуз                   Бананы            237
# 6346              Арбуз                  Кабачки            229
# 2563  Огурцы Луховицкие        Персики армянские            224
# 2508  Огурцы Луховицкие              Лук зеленый            221
# 634        Лук репчатый                  Кабачки            206
# 5506  Помидоры Парадайз                    Укроп            205
# 4825        Лук зеленый                 Петрушка            204
# 6389              Арбуз  Персики азербайджанские            203
# 5354           Петрушка                    Кинза            201
# 622        Лук репчатый                    Арбуз            201
# 6380              Арбуз        Персики армянские            200

# %% [markdown]
# Итак, мы получили датафрейм со встречаемостью всевозможных пар продуктов в нашем магазине. Нельзя, например, не отметить тот факт, что потребители часто покупают разную зелень вместе (Укроп-Петрушка-Кинза-Лук зеленый и т.д.) - такие комбинации встречаются очень часто, или овощи с овощами (Огурцы-Кабачки-Баклажаны-Лук репчатый-Помидоры Парадайз), фрукты с фруктами(Персики армянские - Персики азербайджанские), ягоды с ягодами, орехи с орехами.
#
#
# Можно взять топ-30 по встречаемости пар и закончить на этом наш анализ. Но будет ли это означать, что эти продукты покупатели действительно часто берут вместе (в паре), или же это значит лишь просто то, что первый и/или второй продукт очень популярны, и часто попадают в корзину потребителя друг с другом (при этом эти товары не матчатся друг с другом, как например, Арбуз и Огурцы Луховицкие - третья пара по встречаемости, или Укроп-Арбуз). Если не рассматривать такой вариант событий, то можно просто взять топ-15 самых популярных товаров в магазине и разместить их на одной полке, что приведет скорее к убыткам магазинов, чем если бы самые популярные товары лежали бы вдалеке друг от друга, но при этом рядом с ними лежали бы сопутствующие товары, которые действительно могут идти в паре с другими. Поэтому есть смысл поискать интересные паттерны, выкинув из датафрейма самые популярные продукты, или посмотреть комбинации популярных продуктов и непопулярных.

# %%
# Посмотрим, сколько раз купили каждый продукт (число_покупок), и посчитаем процент покупок (percent), в которых этот 
# продукт присутствует, чтобы оценить "популярность" каждого продукта:

products_df = data["Товар"].value_counts().to_frame()
products_df = products_df.rename(columns={"Товар": "число_покупок"})
products_df["percent"] = round(
    data["Товар"].value_counts().to_frame().mul(100) / data["id"].nunique(), 2
)
products_df
# Out:
#                          число_покупок  percent
# Огурцы Луховицкие                 1022    31.23
# Арбуз                              978    29.88
# Укроп                              828    25.30
# Бананы                             691    21.11
# Кабачки                            662    20.23
# ...                                ...      ...
# Лук-резанец (шнитт-лук)            124     3.79
# Барбарис сушеный                   121     3.70
# Капуста белокочанная               121     3.70
# Яблоки сушеные                     119     3.64
# Абрикос вяленый                    111     3.39
#
# [199 rows x 2 columns]

# %%
# Например, самый популярный продукт - Огурцы Луховицкие - есть в 31% покупок или ~ в каждой третьей покупке! Встречаемость
# данного товара в паре практически с любым другим продуктом будет высокой. 

data3[(data3['1_Товар'] == 'Огурцы Луховицкие') | (data3['2_Товар'] == 'Огурцы Луховицкие')]
# Out:
#                 1_Товар            2_Товар  Встречаемость
# 2514  Огурцы Луховицкие              Укроп            431
# 2517  Огурцы Луховицкие              Арбуз            345
# 2529  Огурцы Луховицкие            Кабачки            326
# 2511  Огурцы Луховицкие           Петрушка            286
# 600        Лук репчатый  Огурцы Луховицкие            285
# ...                 ...                ...            ...
# 2612  Огурцы Луховицкие       Рычал-Су, 1л             47
# 2597  Огурцы Луховицкие      Открытка Love             47
# 2616  Огурцы Луховицкие     Яблоки сушеные             43
# 2603  Огурцы Луховицкие           Рамбутан             41
# 2611  Огурцы Луховицкие    Абрикос вяленый             37
#
# [198 rows x 3 columns]

# %%
# Поэтому есть смысл рассмотреть комбинации из не самых популярных продуктов, н-р, не из топ-15.
# Список 15 самых популярных продуктов (эти товары встречаются более чем в 15% покупок):

list_of_tops = list(data['Товар'].value_counts().index)[:15]
list_of_tops
# Out:
# ['Огурцы Луховицкие',
#  'Арбуз',
#  'Укроп',
#  'Бананы',
#  'Кабачки',
#  'Лук репчатый',
#  'Персики азербайджанские',
#  'Баклажаны грунтовые',
#  'Персики армянские',
#  'Петрушка',
#  'Помидоры Парадайз',
#  'Кинза',
#  'Абрикосы молдавские',
#  'Лук зеленый',
#  'Кукуруза свежая']

# %%
# Датафрейм с товарами не из топ-15 по популярности:
data4 = data3[~data3['1_Товар'].isin(list_of_tops) & ~data3['2_Товар'].isin(list_of_tops)]

# При этом будем рассматривать только пары товаров, встречаемость которых выше 95% пар - такую встречаемость будем считать 
# высокой,т.е. будем искать паттерны только среди 5% самых часто встречающихся пар:

data4 = data4[data4['Встречаемость'] > data3['Встречаемость'].quantile(0.95)]
data4
# Out:
#                  1_Товар             2_Товар  Встречаемость
# 3064    Черешня отборная      Черника свежая             87
# 14                 Лимон   Огурцы Белоруссия             81
# 4                  Лимон     Морковь немытая             80
# 56                 Лимон      Чеснок молодой             76
# 989      Морковь немытая   Огурцы Белоруссия             76
# 106                Лимон                Мята             75
# 8533       Морковь мытая      Чеснок молодой             74
# 7                  Лимон     Капуста цветная             70
# 11342    Миндаль жареный      Фундук жареный             70
# 2973   Огурцы Белоруссия               Редис             70
# 2906   Огурцы Белоруссия      Чеснок молодой             69
# 14130      Миндаль сырой        Фундук сырой             68
# 20                 Лимон  Апельсины столовые             68
# 48                 Лимон       Морковь мытая             68
# 11402    Миндаль жареный       Кешью жареный             68
# 982      Морковь немытая     Капуста цветная             64
# 8622       Морковь мытая           Нектарины             64
# 123                Лимон               Редис             63
# 2898   Огурцы Белоруссия       Морковь мытая             62
# 3088    Черешня отборная      Чеснок молодой             62
# 196                Лимон    Авокадо стандарт             62
# 14059      Миндаль сырой         Кешью сырой             61
# 15                 Лимон    Черешня отборная             61
# 1604     Капуста цветная      Чеснок молодой             61
# 2995   Огурцы Белоруссия           Нектарины             60
# 2865   Огурцы Белоруссия    Черешня отборная             60
# 9714      Чеснок молодой              Щавель             58
# 2891   Огурцы Белоруссия   Персики узбекские             58
# 18                 Лимон       Грибы лисички             57
# 2988   Огурцы Белоруссия    Грибы шампиньоны             57
# 2882   Огурцы Белоруссия      Черника свежая             57
# 3177    Черешня отборная           Нектарины             57
# 1562     Капуста цветная   Огурцы Белоруссия             57
# 1026     Морковь немытая              Шпинат             56
# 163                Лимон       Имбирь корень             56
# 1101     Морковь немытая              Свекла             56
# 1031     Морковь немытая      Чеснок молодой             56
# 8582       Морковь мытая             Цуккини             55
# 2948   Огурцы Белоруссия      Огурцы Миринда             55
# 1596     Капуста цветная       Морковь мытая             55
# 9727      Чеснок молодой     Базилик зеленый             55
# 98                 Лимон      Огурцы Миринда             55
# 94                 Лимон     Базилик зеленый             54
# 9719      Чеснок молодой     Базилик красный             54
# 86                 Лимон     Базилик красный             54
# 1056     Морковь немытая              Щавель             54
# 3084    Черешня отборная       Вишня садовая             53
# 81                 Лимон              Щавель             53
# 2936   Огурцы Белоруссия     Базилик красный             52
# 145                Лимон           Нектарины             52
# 6029      Черника свежая      Чеснок молодой             52
# 1098     Морковь немытая               Редис             52

# %% [markdown]
# В этом датафрейме можно заметить более интересные паттерны, н-р, Черешня-Черника/Вишня, Лимон-Чеснок/Мята/Корень Имбиря/Авокадо,  Чеснок-Базилик, Миндаль-Фундук-Кешью (жареные\сырые), Морковь-Свекла/Шпинат/Щавель и т.д.
# Можно также увеличить список исключенных популярных продуктов до 20 и получить еще пару популярных пар: Капуста цветная - Морковь, Морковь - Цуккини, Черешня - Нектарины.
